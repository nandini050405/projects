# %%
import pandas as pd

# %%
laptop =pd.read_csv(r"C:\Users\nandi\Desktop\data science\1st-july-data-science-\projects\laptopPrice.csv")
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
laptop.info
# Out:
# <bound method DataFrame.info of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
laptop.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
laptop.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
laptop.head(10)
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 8  Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# ...

# %%
laptop.tail(10)
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 813    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 814    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 815    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 816    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 817    ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# ...

# %%
laptop.brand
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: object

# %%
laptop.hdd
# Out:
# 0      1024 GB
# 1      1024 GB
# 2      1024 GB
# 3         0 GB
# 4       512 GB
#         ...
# 818       0 GB
# 819       0 GB
# 820       0 GB
# 821       0 GB
# 822       0 GB
# Name: hdd, Length: 823, dtype: object

# %%
laptop['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
laptop['processor_brand'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Intel
# 1      Intel
# 2      Intel
# 3      Intel
# 4      Intel
#        ...
# 818      AMD
# 819      AMD
# 820      AMD
# 821      AMD
# 822      AMD
# Name: processor_brand, Length: 823, dtype: object>

# %%
laptop['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
laptop['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
laptop['ssd'].nunique()
# Out:
# 7

# %%
laptop.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
brand_b=laptop[laptop['brand']=='APPLE']
brand_b
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
after=brand_b[brand_b['Price']>=40000]
after
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
after[after['ram_type']=='DDR4']
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
after.duplicated()
# Out:
# 309    False
# 310    False
# 407    False
# 408    False
# 599    False
# 600    False
# 601    False
# 602     True
# 603    False
# 604     True
# 605     True
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616     True
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# 622     True
# dtype: bool

# %%
after.duplicated().sum
# Out:
# <bound method Series.sum of 309    False
# 310    False
# 407    False
# 408    False
# 599    False
# 600    False
# 601    False
# 602     True
# 603    False
# 604     True
# 605     True
# 606    False
# 607    False
# 608    False
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616     True
# 617    False
# 618    False
# 619    False
# 620    False
# 621    False
# 622     True
# dtype: bool>

# %%
after.drop_duplicates(inplace=True)
after
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
after.count
# Out:
# <bound method DataFrame.count of      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
after.shape
# Out:
# (23, 19)

# %%
laptop.query('brand=="APPLE" and Price>= 20000 and processor_brand=="Intel"')
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 407  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 408  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13
# ...

# %%
laptop.query('brand=="APPLE" and ram_gb=="8 GB" and ssd=="256 GB"')
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 599  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 600  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 602  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 605  256 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 599       No   85990  4 stars               6725                629
# 600       No  112990  4 stars                640                 70
# ...

# %%
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
laptop.to_csv('Used_laptop_cleaned.csv', index=False)
laptop
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
char=laptop.select_dtypes(include='object')

# %%
char
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num=laptop.select_dtypes(exclude='object')
num
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
char['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
char['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
char['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
brand_dict={
    'First brand' :1,
    'Second brand':2,
    'Third brand' :3,
    'Fourth brand or More':4
}
brand_dict
# Out:
# {'First brand': 1,
#  'Second brand': 2,
#  'Third brand': 3,
#  'Fourth brand or More': 4}

# %%
char['brand']=char['brand'].map(brand_dict)
char
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      NaN           Intel        Core i3            10th   4 GB     DDR4
# 1      NaN           Intel        Core i3            10th   4 GB     DDR4
# 2      NaN           Intel        Core i3            10th   4 GB     DDR4
# 3      NaN           Intel        Core i5            10th   8 GB     DDR4
# 4      NaN           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818    NaN             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    NaN             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    NaN             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    NaN             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822    NaN             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

char['processor_brand']=le.fit_transform(char['processor_brand'])

# %%
char
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      NaN                1        Core i3            10th   4 GB     DDR4
# 1      NaN                1        Core i3            10th   4 GB     DDR4
# 2      NaN                1        Core i3            10th   4 GB     DDR4
# 3      NaN                1        Core i5            10th   8 GB     DDR4
# 4      NaN                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 819    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 820    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 821    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 822    NaN                0        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
clean_data =pd.concat([char,num],axis=1)

# %%
clean_data
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      NaN                1        Core i3            10th   4 GB     DDR4
# 1      NaN                1        Core i3            10th   4 GB     DDR4
# 2      NaN                1        Core i3            10th   4 GB     DDR4
# 3      NaN                1        Core i5            10th   8 GB     DDR4
# 4      NaN                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 819    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 820    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 821    NaN                0        Ryzen 9   Not Available   4 GB     DDR4
# 822    NaN                0        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
